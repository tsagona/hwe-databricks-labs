-- %% [markdown]
-- # Drop Gold Schema and Tables

-- %% [markdown]
-- ## Setup: Set Your Catalog
--
-- **IMPORTANT:** Before running any queries, set your assigned catalog name.

-- %%
-- TODO: Replace with your assigned catalog name
USE CATALOG your_catalog_name;

-- %%
-- TODO: Drop the gold.fact_sales table

-- %%
-- TODO: Drop the gold.dim_customer table

-- %%
-- TODO: Drop the gold.dim_store table

-- %%
-- TODO: Drop the gold.dim_book table

-- %%
-- TODO: Drop the gold.dim_date table

-- %%
-- TODO: Drop the gold schema (use CASCADE to drop all tables)
